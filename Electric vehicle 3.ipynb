# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline
import seaborn as sns

data=files.upload()
# Out:
#      <input type="file" id="files-284148b2-d3bc-4f61-ba7a-e886ce7112d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-284148b2-d3bc-4f61-ba7a-e886ce7112d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ev = pd.read_csv('EVIndia.csv')

# %%
ev.isnull().sum()
# Out:
# Car             0
# Style           0
# Range           0
# Transmission    0
# VehicleType     0
# PriceRange      0
# Capacity        0
# BootSpace       0
# BaseModel       0
# TopModel        0
# dtype: int64

# %%
ev.shape
# Out:
# (12, 10)

# %%
ev.describe()
# Out:
#                   Car        Style               Range Transmission  \
# count              12           12                  12           12
# unique             12            7                  12            1
# top     Tata Nexon EV  Compact SUV  312 Km/Full Charge    Automatic
# freq                1            6                   1           12
#
#        VehicleType        PriceRange   Capacity BootSpace BaseModel TopModel
# count           12                12         12        12        12       12
# unique           1                12          2         8         9        7
# top       Electric  ₹ 13.99 - 17.4 L  5 Seater         na        na       na
# freq            12                 1         11         4         4        6

# %%
ev.head()
# Out:
#                      Car             Style               Range Transmission  \
# 0          Tata Nexon EV       Compact SUV  312 Km/Full Charge    Automatic
# 1          Tata Tigor EV  Subcompact Sedan  306 Km/Full Charge    Automatic
# 2      Tata Nexon EV Max       Compact SUV  437 Km/Full Charge    Automatic
# 3               MG ZS EV       Compact SUV  419 Km/Full Charge    Automatic
# 4  Hyundai Kona Electric       Compact SUV  452 Km/Full Charge    Automatic
#
#   VehicleType         PriceRange   Capacity BootSpace           BaseModel  \
# 0    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L                 XM
# 1    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L                 XE
# 2    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L     XZ Plus 3.3 kW
# 3    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L             Excite
# 4    Electric  ₹ 23.79 - 23.98 L  5 Seater         na  Premium Dual Tone
#
#               TopModel
# 0    Dark XZ Plus LUX
# ...

# %%
ev['Car'].value_counts()
# Out:
# Tata Nexon EV            1
# Tata Tigor EV            1
# Tata Nexon EV Max        1
# MG ZS EV                 1
# Hyundai Kona Electric    1
# Jaguar I-Pace            1
# Audi E-Tron GT           1
# BYD E6                   1
# Mercedes-Benz EQC        1
# BMW iX                   1
# Porsche Taycan           1
# Audi E-Tron              1
# Name: Car, dtype: int64

# %%
ev['Capacity'].value_counts()
# Out:
# 5 Seater     11
# 4 Seater      1
# Name: Capacity, dtype: int64

# %%
# Count the frequency of each category
style_counts = ev['Style'].value_counts()
# Create a list of colors for each category
colors = ['green', 'blue', 'cyan', 'red', 'purple', 'pink']

# Create a bar plot
plt.bar(style_counts.index, style_counts.values, color=colors)

# Set the labels and title
plt.xlabel('Style')
plt.ylabel('Count')
plt.title('Different style of Car Capacity')
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Count the frequency of each category
car_counts = ev['Car'].value_counts()
# Create a list of colors for each category
colors = ['green', 'blue', 'pink', 'orange', 'purple', 'red']

# Create a bar plot
plt.bar(car_counts.index, car_counts.values, color=colors)

# Set the labels and title
plt.xlabel('Car model')
plt.ylabel('Count')
plt.title('Different brands of Car Capacity')
plt.xticks(rotation=70)

# Display the plot
plt.show()

# %%
# Extract the numeric value from the 'Range' column
ev['Range'] = ev['Range'].str.extract('(\d+)', expand=False).astype(float)

# %%
ev.head()
# Out:
#                      Car             Style  Range Transmission VehicleType  \
# 0          Tata Nexon EV       Compact SUV  312.0    Automatic    Electric
# 1          Tata Tigor EV  Subcompact Sedan  306.0    Automatic    Electric
# 2      Tata Nexon EV Max       Compact SUV  437.0    Automatic    Electric
# 3               MG ZS EV       Compact SUV  419.0    Automatic    Electric
# 4  Hyundai Kona Electric       Compact SUV  452.0    Automatic    Electric
#
#           PriceRange   Capacity BootSpace           BaseModel  \
# 0   ₹ 13.99 - 17.4 L  5 Seater      350 L                 XM
# 1  ₹ 12.49 - 13.64 L  5 Seater      316 L                 XE
# 2  ₹ 17.74 - 19.24 L  5 Seater      350 L     XZ Plus 3.3 kW
# 3  ₹ 21.99 - 25.88 L  5 Seater      448 L             Excite
# 4  ₹ 23.79 - 23.98 L  5 Seater         na  Premium Dual Tone
#
#               TopModel
# 0    Dark XZ Plus LUX
# 1   XZ Plus Dual Tone
# 2  XZ Plus Lux 7.2 kW
# 3           Exclusive
# 4                 HSE

# %%
# Calculate the frequency/count of each range
range_counts = ev['Range'].value_counts()
# Create a pie plot
plt.pie(range_counts.values, labels=range_counts.index, autopct='%1.1f%%')

# Set the title
plt.title('Distribution of Range')

# Display the plot
plt.show()

# %%
# Sort the DataFrame by 'Range' column in descending order and select the top 10 cars
top_10_cars = ev.nlargest(10, 'Range')

# Create a list of colors for each category
colors = ['pink', 'blue', 'red', 'green', 'purple', 'orange']

# Create a bar plot for the top 10 cars and their ranges
plt.bar(top_10_cars['Car'], top_10_cars['Range'], color=colors)

# Set the labels and title
plt.xlabel('Car')
plt.ylabel('Range (Km/Full Charge)')
plt.title('Top 10 Cars by Range')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=70)

# Display the plot
plt.show()
