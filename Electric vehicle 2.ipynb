# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline
import seaborn as sns
data=files.upload()
# Out:
#      <input type="file" id="files-53a696c5-84eb-4995-826c-ed855308c23d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53a696c5-84eb-4995-826c-ed855308c23d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ev = pd.read_csv('ev_india.csv')
ev.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
# Group the data by brand and calculate the maximum top speed
brand_top_speeds = ev.groupby('Brand')['TopSpeed_KmH'].max().nlargest(10)

# Create a list of colors for each category
colors = ['green', 'red', 'pink', 'blue', 'purple', 'cyan']

# Create a bar plot for the top speeds by brand
plt.bar(brand_top_speeds.index, brand_top_speeds.values, color=colors)

# Set the labels and title
plt.xlabel('Brand')
plt.ylabel('Top Speed (Km/H)')
plt.title('Top 10 Car Brands by Top Speed')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Count the frequency of each RapidCharge category
rapid_charge_counts = ev['RapidCharge'].value_counts()

# Create a pie plot
plt.pie(rapid_charge_counts.values, labels=rapid_charge_counts.index, autopct='%1.1f%%')

# Set the title
plt.title('Distribution of Rapid Charge')

# Display the plot
plt.show()

# %%
# Count the frequency of each body style category
body_style_counts = ev['BodyStyle'].value_counts()

# Create a list of colors for each category
colors = ['pink', 'red', 'green', 'blue', 'purple', 'cyan']

# Create a bar plot
plt.bar(body_style_counts.index, body_style_counts.values, color=colors)

# Set the labels and title
plt.xlabel('Body Style')
plt.ylabel('Count')
plt.title('Distribution of Body Style')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = ev.corr()

# Create a heatmap using the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Set the title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()
# Out:
# <ipython-input-7-d9900b318d5d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ev.corr()
